# %%
import pandas as pd

# %%
import numpy as np
import statsmodels.api as sm

# %%
df = pd.read_csv("for_modelling.csv")
df.sample(10)
# Out:
#        Unnamed: 0  marital_cat  education_cat  default_cat  loan_cat  \
# 36437       36437            1              1            1         1
# 16131       16131            1              1            0         0
# 16137       16137            1              1            1         0
# 2473         2473            1              1            1         1
# 21906       21906            1              1            1         1
# 38680       38680            1              1            1         1
# 5898         5898            1              1            1         0
# 37602       37602            1              0            1         1
# 38794       38794            1              0            1         1
# 39387       39387            1              1            1         1
#
#        contact_cat  housing_cat  campaign_cat1  campaign_cat2  poutcome_cat  \
# 36437            1            0              1              1             1
# ...

# %%
df.drop(columns=['campaign_cat1'],inplace=True)
df.columns
# Out:
# Index(['Unnamed: 0', 'marital_cat', 'education_cat', 'default_cat', 'loan_cat',
#        'contact_cat', 'housing_cat', 'campaign_cat2', 'poutcome_cat',
#        'day_cat', 'y_bool', 'age_cat', 'balance', 'duration'],
#       dtype='object')

# %%
# y=mx+b , setting up regression where y is dependent var and x is list of input vars

y = df.y_bool
x_columns = df.columns.tolist()[1:9] + df.columns.tolist()[-3:]
x = df[x_columns]

# %%
# executing log regression

log_reg = sm.Logit(y, x).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.278343
#          Iterations 7

# %%
print(log_reg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                 y_bool   No. Observations:                45211
# Model:                          Logit   Df Residuals:                    45200
# Method:                           MLE   Df Model:                           10
# Date:                Fri, 19 Jan 2024   Pseudo R-squ.:                  0.2287
# Time:                        13:00:53   Log-Likelihood:                -12584.
# converged:                       True   LL-Null:                       -16315.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# marital_cat      -0.6352      0.044    -14.456      0.000      -0.721      -0.549
# education_cat    -0.1671      0.040     -4.156      0.000      -0.246      -0.088
# ...

# %%
# true positive

df[(df_evaluate.Survived_Actual == 1) & (df_evaluate.Survival_Binary == 1)].shape[0]
